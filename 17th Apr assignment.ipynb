# %% [markdown]
# Q1. What is Gradient Boosting Regression?

# %% [markdown]
# Gradient boosting regression is a machine learning algorithm that combines multiple weak learners to create a strong learner. A weak learner is a model that is only slightly better than random guessing. By combining multiple weak learners, gradient boosting regression can create a model that is much more accurate than any individual weak learner.

# %% [markdown]
# Q2. Implement a simple gradient boosting algorithm from scratch using Python and NumPy. Use a
# simple regression problem as an example and train the model on a small dataset. Evaluate the model's
# performance using metrics such as mean squared error and R-squared.

# %%
from sklearn.datasets import make_regression
X,y = make_regression(n_samples=100, n_features=4,n_targets=1)

# %%
y
# Out:
# array([-1.01130564e+02, -1.48815101e+02, -2.11758871e+01, -2.10956680e+02,
#        -4.91657706e+01, -2.56322325e+01, -1.07314499e+02,  4.30424458e+01,
#        -8.40626990e+01, -1.40445533e+02, -4.49963088e+01, -1.95261075e+01,
#         2.17417791e+02, -2.96020611e+01, -5.34976148e+01,  1.97361644e+02,
#        -2.39022038e+01,  8.96173602e+01, -3.06040417e+01, -1.41563633e+02,
#        -5.86527527e+01, -2.16346072e+02,  1.81852799e+02, -2.09848836e+02,
#        -9.95472600e-02, -1.01805194e+02,  8.93906320e+00,  1.85470958e+02,
#         5.19965180e+01, -1.96716557e+02, -5.13465205e+00, -1.21693724e+02,
#        -6.14259922e+01,  7.15624334e+01,  1.90636394e+02,  3.07438012e+00,
#        -2.48726544e+01, -9.14929067e+01,  1.28124250e+02, -5.15972992e+01,
#         3.75048946e+01,  6.34553808e+01, -8.63540750e+01, -1.16347234e+02,
#        -2.72372832e+01, -1.53569157e+01,  1.64756869e+01, -1.17022698e+01,
#        -1.24170421e+02,  1.12346731e+02, -1.25590631e+02, -1.34698733e+02,
#         1.46830633e+02, -1.65329729e+01,  1.24349484e+02, -5.66830691e+01,
#        -4.45903451e+01, -1.03367046e+02, -5.31821373e+01, -1.06544294e+02,
#        -4.97435515e+01,  1.29236646e+01,  4.77713065e+01,  4.29320471e+01,
#        -1.40019111e+02,  1.66942747e+02, -3.52402215e+01, -1.01010012e+02,
#         2.25407846e+01,  9.83410831e+01, -9.20124494e+01,  1.16146538e+02,
#        -2.00953898e+02,  5.30666419e+01,  1.19481809e+02,  5.34055938e+01,
#         9.08718566e+01, -5.77491902e+01, -3.11455034e+01, -8.57155950e+00,
#         8.04668298e+00, -1.55454537e+02, -2.09453362e+02, -3.85541360e+01,
#        -1.20777277e+02, -7.70855242e+01,  1.40279440e+02, -7.29866560e+01,
#         2.01730543e+02,  1.11263305e+01,  2.07186155e+02,  4.75320665e+01,
#         9.40469607e+01, -5.07130110e+01, -6.16088064e+01, -7.13674978e-01,
#        -1.35668056e+02,  6.63019841e+01, -1.21395843e+02,  1.41042635e+02])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import GradientBoostingRegressor
regressor = GradientBoostingRegressor()
regressor.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
print(f"mse: {mean_squared_error(y_pred, y_test)}")
print(f"mae: {mean_absolute_error(y_pred, y_test)}")
print(f"R_squared: {r2_score(y_pred, y_test)}")
# Out:
# mse: 1330.836486283171
# mae: 28.049259895072016
# R_squared: 0.8484242661440771

# %% [markdown]
# Q3. Experiment with different hyperparameters such as learning rate, number of trees, and tree depth to
# optimise the performance of the model. Use grid search or random search to find the best
# hyperparameters

# %%
parameter = {'learning_rate' : [0.1,1,10],
             'n_estimators' : [10,100,200],
             'max_depth': [1,3,5],
             'loss': ['squared_error', 'absolute_error', 'quantile'],
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(regressor, param_grid=parameter,refit=True,cv=3,verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV 1/3] END learning_rate=0.1, loss=squared_error, max_depth=1, n_estimators=10;, score=0.339 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=squared_error, max_depth=1, n_estimators=10;, score=0.470 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=squared_error, max_depth=1, n_estimators=10;, score=0.360 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=squared_error, max_depth=1, n_estimators=100;, score=0.829 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=squared_error, max_depth=1, n_estimators=100;, score=0.864 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=squared_error, max_depth=1, n_estimators=100;, score=0.854 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=squared_error, max_depth=1, n_estimators=200;, score=0.881 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=squared_error, max_depth=1, n_estimators=200;, score=0.902 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=squared_error, max_depth=1, n_estimators=200;, score=0.897 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=squared_error, max_depth=3, n_estimators=10;, score=0.632 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=squared_error, max_depth=3, n_estimators=10;, score=0.705 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=squared_error, max_depth=3, n_estimators=10;, score=0.602 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=squared_error, max_depth=3, n_estimators=100;, score=0.832 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=squared_error, max_depth=3, n_estimators=100;, score=0.919 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=squared_error, max_depth=3, n_estimators=100;, score=0.850 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=squared_error, max_depth=3, n_estimators=200;, score=0.832 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=squared_error, max_depth=3, n_estimators=200;, score=0.925 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=squared_error, max_depth=3, n_estimators=200;, score=0.850 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=squared_error, max_depth=5, n_estimators=10;, score=0.614 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=squared_error, max_depth=5, n_estimators=10;, score=0.778 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=squared_error, max_depth=5, n_estimators=10;, score=0.605 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=squared_error, max_depth=5, n_estimators=100;, score=0.790 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=squared_error, max_depth=5, n_estimators=100;, score=0.845 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=squared_error, max_depth=5, n_estimators=100;, score=0.809 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=squared_error, max_depth=5, n_estimators=200;, score=0.799 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=squared_error, max_depth=5, n_estimators=200;, score=0.851 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=squared_error, max_depth=5, n_estimators=200;, score=0.813 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=absolute_error, max_depth=1, n_estimators=10;, score=0.198 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=absolute_error, max_depth=1, n_estimators=10;, score=0.463 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=absolute_error, max_depth=1, n_estimators=10;, score=0.303 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=absolute_error, max_depth=1, n_estimators=100;, score=0.705 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=absolute_error, max_depth=1, n_estimators=100;, score=0.890 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=absolute_error, max_depth=1, n_estimators=100;, score=0.785 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=absolute_error, max_depth=1, n_estimators=200;, score=0.850 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, loss=absolute_error, max_depth=1, n_estimators=200;, score=0.870 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, loss=absolute_error, max_depth=1, n_estimators=200;, score=0.885 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, loss=absolute_error, max_depth=3, n_estimators=10;, score=0.447 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=absolute_error, max_depth=3, n_estimators=10;, score=0.678 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=absolute_error, max_depth=3, n_estimators=10;, score=0.564 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=absolute_error, max_depth=3, n_estimators=100;, score=0.846 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, loss=absolute_error, max_depth=3, n_estimators=100;, score=0.911 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, loss=absolute_error, max_depth=3, n_estimators=100;, score=0.855 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, loss=absolute_error, max_depth=3, n_estimators=200;, score=0.862 total time=   0.4s
# [CV 2/3] END learning_rate=0.1, loss=absolute_error, max_depth=3, n_estimators=200;, score=0.884 total time=   0.3s
# [CV 3/3] END learning_rate=0.1, loss=absolute_error, max_depth=3, n_estimators=200;, score=0.891 total time=   0.3s
# [CV 1/3] END learning_rate=0.1, loss=absolute_error, max_depth=5, n_estimators=10;, score=0.451 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=absolute_error, max_depth=5, n_estimators=10;, score=0.693 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=absolute_error, max_depth=5, n_estimators=10;, score=0.575 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=absolute_error, max_depth=5, n_estimators=100;, score=0.859 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, loss=absolute_error, max_depth=5, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, loss=absolute_error, max_depth=5, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, loss=absolute_error, max_depth=5, n_estimators=200;, score=0.832 total time=   0.5s
# [CV 2/3] END learning_rate=0.1, loss=absolute_error, max_depth=5, n_estimators=200;, score=0.895 total time=   0.5s
# [CV 3/3] END learning_rate=0.1, loss=absolute_error, max_depth=5, n_estimators=200;, score=0.890 total time=   0.5s
# [CV 1/3] END learning_rate=0.1, loss=quantile, max_depth=1, n_estimators=10;, score=-0.318 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=quantile, max_depth=1, n_estimators=10;, score=-3.510 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=quantile, max_depth=1, n_estimators=10;, score=-1.768 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=quantile, max_depth=1, n_estimators=100;, score=0.251 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=quantile, max_depth=1, n_estimators=100;, score=-1.392 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=quantile, max_depth=1, n_estimators=100;, score=-0.926 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=quantile, max_depth=1, n_estimators=200;, score=0.368 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, loss=quantile, max_depth=1, n_estimators=200;, score=-1.355 total time=   0.3s
# [CV 3/3] END learning_rate=0.1, loss=quantile, max_depth=1, n_estimators=200;, score=-0.862 total time=   0.2s
# [CV 1/3] END learning_rate=0.1, loss=quantile, max_depth=3, n_estimators=10;, score=-0.025 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=quantile, max_depth=3, n_estimators=10;, score=-2.311 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=quantile, max_depth=3, n_estimators=10;, score=-1.328 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=quantile, max_depth=3, n_estimators=100;, score=0.655 total time=   0.1s
# [CV 2/3] END learning_rate=0.1, loss=quantile, max_depth=3, n_estimators=100;, score=-0.594 total time=   0.1s
# [CV 3/3] END learning_rate=0.1, loss=quantile, max_depth=3, n_estimators=100;, score=0.073 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, loss=quantile, max_depth=3, n_estimators=200;, score=0.746 total time=   0.3s
# [CV 2/3] END learning_rate=0.1, loss=quantile, max_depth=3, n_estimators=200;, score=0.471 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, loss=quantile, max_depth=3, n_estimators=200;, score=0.391 total time=   0.3s
# [CV 1/3] END learning_rate=0.1, loss=quantile, max_depth=5, n_estimators=10;, score=-0.003 total time=   0.0s
# [CV 2/3] END learning_rate=0.1, loss=quantile, max_depth=5, n_estimators=10;, score=-2.209 total time=   0.0s
# [CV 3/3] END learning_rate=0.1, loss=quantile, max_depth=5, n_estimators=10;, score=-1.267 total time=   0.0s
# [CV 1/3] END learning_rate=0.1, loss=quantile, max_depth=5, n_estimators=100;, score=0.738 total time=   0.2s
# [CV 2/3] END learning_rate=0.1, loss=quantile, max_depth=5, n_estimators=100;, score=0.134 total time=   0.2s
# [CV 3/3] END learning_rate=0.1, loss=quantile, max_depth=5, n_estimators=100;, score=0.457 total time=   0.1s
# [CV 1/3] END learning_rate=0.1, loss=quantile, max_depth=5, n_estimators=200;, score=0.771 total time=   0.3s
# [CV 2/3] END learning_rate=0.1, loss=quantile, max_depth=5, n_estimators=200;, score=0.394 total time=   0.3s
# [CV 3/3] END learning_rate=0.1, loss=quantile, max_depth=5, n_estimators=200;, score=0.293 total time=   0.5s
# [CV 1/3] END learning_rate=1, loss=squared_error, max_depth=1, n_estimators=10;, score=0.819 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=squared_error, max_depth=1, n_estimators=10;, score=0.689 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=squared_error, max_depth=1, n_estimators=10;, score=0.837 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=squared_error, max_depth=1, n_estimators=100;, score=0.893 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=squared_error, max_depth=1, n_estimators=100;, score=0.797 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=squared_error, max_depth=1, n_estimators=100;, score=0.818 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=squared_error, max_depth=1, n_estimators=200;, score=0.896 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=squared_error, max_depth=1, n_estimators=200;, score=0.803 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=squared_error, max_depth=1, n_estimators=200;, score=0.812 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=squared_error, max_depth=3, n_estimators=10;, score=0.511 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=squared_error, max_depth=3, n_estimators=10;, score=0.796 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=squared_error, max_depth=3, n_estimators=10;, score=0.770 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=squared_error, max_depth=3, n_estimators=100;, score=0.530 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=squared_error, max_depth=3, n_estimators=100;, score=0.737 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=squared_error, max_depth=3, n_estimators=100;, score=0.779 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=squared_error, max_depth=3, n_estimators=200;, score=0.493 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=squared_error, max_depth=3, n_estimators=200;, score=0.789 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=squared_error, max_depth=3, n_estimators=200;, score=0.795 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=squared_error, max_depth=5, n_estimators=10;, score=0.557 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=squared_error, max_depth=5, n_estimators=10;, score=0.644 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=squared_error, max_depth=5, n_estimators=10;, score=0.814 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=squared_error, max_depth=5, n_estimators=100;, score=0.659 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=squared_error, max_depth=5, n_estimators=100;, score=0.801 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=squared_error, max_depth=5, n_estimators=100;, score=0.816 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=squared_error, max_depth=5, n_estimators=200;, score=0.642 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=squared_error, max_depth=5, n_estimators=200;, score=0.733 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=squared_error, max_depth=5, n_estimators=200;, score=0.794 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=absolute_error, max_depth=1, n_estimators=10;, score=0.727 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=absolute_error, max_depth=1, n_estimators=10;, score=0.832 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=absolute_error, max_depth=1, n_estimators=10;, score=0.769 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=absolute_error, max_depth=1, n_estimators=100;, score=0.837 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=absolute_error, max_depth=1, n_estimators=100;, score=0.866 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=absolute_error, max_depth=1, n_estimators=100;, score=0.879 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=absolute_error, max_depth=1, n_estimators=200;, score=0.805 total time=   0.1s
# [CV 2/3] END learning_rate=1, loss=absolute_error, max_depth=1, n_estimators=200;, score=0.873 total time=   0.1s
# [CV 3/3] END learning_rate=1, loss=absolute_error, max_depth=1, n_estimators=200;, score=0.879 total time=   0.1s
# [CV 1/3] END learning_rate=1, loss=absolute_error, max_depth=3, n_estimators=10;, score=0.732 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=absolute_error, max_depth=3, n_estimators=10;, score=0.332 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=absolute_error, max_depth=3, n_estimators=10;, score=0.761 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=absolute_error, max_depth=3, n_estimators=100;, score=0.755 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=absolute_error, max_depth=3, n_estimators=100;, score=0.463 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=absolute_error, max_depth=3, n_estimators=100;, score=0.782 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=absolute_error, max_depth=3, n_estimators=200;, score=0.749 total time=   0.1s
# [CV 2/3] END learning_rate=1, loss=absolute_error, max_depth=3, n_estimators=200;, score=0.433 total time=   0.1s
# [CV 3/3] END learning_rate=1, loss=absolute_error, max_depth=3, n_estimators=200;, score=0.741 total time=   0.1s
# [CV 1/3] END learning_rate=1, loss=absolute_error, max_depth=5, n_estimators=10;, score=0.658 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=absolute_error, max_depth=5, n_estimators=10;, score=0.574 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=absolute_error, max_depth=5, n_estimators=10;, score=0.709 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=absolute_error, max_depth=5, n_estimators=100;, score=0.755 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=absolute_error, max_depth=5, n_estimators=100;, score=0.603 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=absolute_error, max_depth=5, n_estimators=100;, score=0.668 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=absolute_error, max_depth=5, n_estimators=200;, score=0.876 total time=   0.1s
# [CV 2/3] END learning_rate=1, loss=absolute_error, max_depth=5, n_estimators=200;, score=0.482 total time=   0.1s
# [CV 3/3] END learning_rate=1, loss=absolute_error, max_depth=5, n_estimators=200;, score=0.686 total time=   0.1s
# [CV 1/3] END learning_rate=1, loss=quantile, max_depth=1, n_estimators=10;, score=-0.131 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=quantile, max_depth=1, n_estimators=10;, score=-0.413 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=quantile, max_depth=1, n_estimators=10;, score=-0.245 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=quantile, max_depth=1, n_estimators=100;, score=0.074 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=quantile, max_depth=1, n_estimators=100;, score=-0.413 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=quantile, max_depth=1, n_estimators=100;, score=0.185 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=quantile, max_depth=1, n_estimators=200;, score=0.074 total time=   0.1s
# [CV 2/3] END learning_rate=1, loss=quantile, max_depth=1, n_estimators=200;, score=-0.413 total time=   0.2s
# [CV 3/3] END learning_rate=1, loss=quantile, max_depth=1, n_estimators=200;, score=0.125 total time=   0.1s
# [CV 1/3] END learning_rate=1, loss=quantile, max_depth=3, n_estimators=10;, score=0.224 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=quantile, max_depth=3, n_estimators=10;, score=-1.078 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=quantile, max_depth=3, n_estimators=10;, score=-0.653 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=quantile, max_depth=3, n_estimators=100;, score=0.225 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=quantile, max_depth=3, n_estimators=100;, score=-1.443 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=quantile, max_depth=3, n_estimators=100;, score=-0.397 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=quantile, max_depth=3, n_estimators=200;, score=0.225 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=quantile, max_depth=3, n_estimators=200;, score=-1.078 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=quantile, max_depth=3, n_estimators=200;, score=-0.653 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=quantile, max_depth=5, n_estimators=10;, score=-0.306 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=quantile, max_depth=5, n_estimators=10;, score=-1.553 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=quantile, max_depth=5, n_estimators=10;, score=-0.637 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=quantile, max_depth=5, n_estimators=100;, score=0.209 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=quantile, max_depth=5, n_estimators=100;, score=-1.557 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=quantile, max_depth=5, n_estimators=100;, score=-0.915 total time=   0.0s
# [CV 1/3] END learning_rate=1, loss=quantile, max_depth=5, n_estimators=200;, score=0.210 total time=   0.0s
# [CV 2/3] END learning_rate=1, loss=quantile, max_depth=5, n_estimators=200;, score=-1.520 total time=   0.0s
# [CV 3/3] END learning_rate=1, loss=quantile, max_depth=5, n_estimators=200;, score=-0.637 total time=   0.1s
# [CV 1/3] END learning_rate=10, loss=squared_error, max_depth=1, n_estimators=10;, score=-7529399714661441536.000 total time=   0.0s
# [CV 2/3] END learning_rate=10, loss=squared_error, max_depth=1, n_estimators=10;, score=-12403451877299083264.000 total time=   0.0s
# [CV 3/3] END learning_rate=10, loss=squared_error, max_depth=1, n_estimators=10;, score=-4340137754046760960.000 total time=   0.0s
# [CV 1/3] END learning_rate=10, loss=squared_error, max_depth=1, n_estimators=100;, score=-43693018868064739630537334597664722057353304212332270431982917285478085810067894732344206741488852191921072667443585752734650348771632425926244084041732570013347805490432184474658025372647424.000 total time=   0.0s
# [CV 2/3] END learning_rate=10, loss=squared_error, max_depth=1, n_estimators=100;, score=-71977086825039454258456957113096173764478195424396661505198316358198837230216834976160811149710774178180992004079321084944455678947095758376047380576661004372999987394181443825598279970717696.000 total time=   0.0s
# [CV 3/3] END learning_rate=10, loss=squared_error, max_depth=1, n_estimators=100;, score=-25185768843976836890359473284870105747078747112711540752771684614327097539073083907871767598920845970899602938815486496616204521054730806828693229252317052182637192760251990603992919344939008.000 total time=   0.0s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# [CV 1/3] END learning_rate=10, loss=squared_error, max_depth=1, n_estimators=200;, score=-inf total time=   0.0s
# [CV 2/3] END learning_rate=10, loss=squared_error, max_depth=1, n_estimators=200;, score=-inf total time=   0.0s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
#   * np.sum(sample_weight * ((y - raw_predictions.ravel()) ** 2))
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb_losses.py:231: RuntimeWarning: overflow encountered in square
# ...
# [CV 2/3] END learning_rate=10, loss=absolute_error, max_depth=1, n_estimators=100;, score=-62789694930776460670158645096692868626789752694576130706736652224670806313544074371637662429862582243039597704617069755624243072073541464702305155895677575713551010510579990743524356942462976.000 total time=   0.0s
# [CV 3/3] END learning_rate=10, loss=absolute_error, max_depth=1, n_estimators=100;, score=-13752218764655779378464496223469690413018365482453121485874586063774527309793464695045425740585167569614851374131002523746950571759469057936377547294513998788907617078826881839003795208536064.000 total time=   0.0s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 1/3] END learning_rate=10, loss=absolute_error, max_depth=1, n_estimators=200;, score=-inf total time=   0.1s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 2/3] END learning_rate=10, loss=absolute_error, max_depth=1, n_estimators=200;, score=-inf total time=   0.1s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 3/3] END learning_rate=10, loss=absolute_error, max_depth=1, n_estimators=200;, score=-inf total time=   0.1s
# [CV 1/3] END learning_rate=10, loss=absolute_error, max_depth=3, n_estimators=10;, score=-6458889778774497280.000 total time=   0.0s
# [CV 2/3] END learning_rate=10, loss=absolute_error, max_depth=3, n_estimators=10;, score=-12546681998271139840.000 total time=   0.0s
# [CV 3/3] END learning_rate=10, loss=absolute_error, max_depth=3, n_estimators=10;, score=-4220516511122179072.000 total time=   0.0s
# [CV 1/3] END learning_rate=10, loss=absolute_error, max_depth=3, n_estimators=100;, score=-37480862164933194360728801654356258521165103110575704436304469898528175334167708582673376338225504289869095820362107321228954328693694701123848818269548225143269340999616204276016692898824192.000 total time=   0.1s
# [CV 2/3] END learning_rate=10, loss=absolute_error, max_depth=3, n_estimators=100;, score=-72808249549476258228882874173297812198879839680917542750417967238871451571098890118453476894957928354270417979801462876732866365330844931075767263084827605979960226699723610050456030166384640.000 total time=   0.1s
# [CV 3/3] END learning_rate=10, loss=absolute_error, max_depth=3, n_estimators=100;, score=-24491608161213301468690952581385940802292674335163260858253379518967217857737356822101226228518258061525684349926705082312056618794795611142973873476850004461068484596660886148543180229836800.000 total time=   0.1s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 1/3] END learning_rate=10, loss=absolute_error, max_depth=3, n_estimators=200;, score=-inf total time=   0.2s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 2/3] END learning_rate=10, loss=absolute_error, max_depth=3, n_estimators=200;, score=-inf total time=   0.2s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 3/3] END learning_rate=10, loss=absolute_error, max_depth=3, n_estimators=200;, score=-inf total time=   0.3s
# [CV 1/3] END learning_rate=10, loss=absolute_error, max_depth=5, n_estimators=10;, score=-6979614572936300544.000 total time=   0.0s
# [CV 2/3] END learning_rate=10, loss=absolute_error, max_depth=5, n_estimators=10;, score=-12978753621715736576.000 total time=   0.0s
# [CV 3/3] END learning_rate=10, loss=absolute_error, max_depth=5, n_estimators=10;, score=-4550690966023083520.000 total time=   0.0s
# [CV 1/3] END learning_rate=10, loss=absolute_error, max_depth=5, n_estimators=100;, score=-40508108581424631757396090615138262239644366742400361323550196961991894972779662540418619196865721624260079304037927109548660258434707681814748020013741769224231249541460294857520144063660032.000 total time=   0.1s
# [CV 2/3] END learning_rate=10, loss=absolute_error, max_depth=5, n_estimators=100;, score=-75303442119678830255171895668605667017079203288495917127765357598807393643857994539265784582670980841256767522143391242629958734807176187968508518134344480313403396547218389205968835013771264.000 total time=   0.1s
# [CV 3/3] END learning_rate=10, loss=absolute_error, max_depth=5, n_estimators=100;, score=-26407606678256200452941615613858404595031967537653211213493589904734126674030801690962445992191767177042486786631024218124226826428509092942148368172665046684083856182203368508410005756575744.000 total time=   0.1s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 1/3] END learning_rate=10, loss=absolute_error, max_depth=5, n_estimators=200;, score=-inf total time=   0.3s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 2/3] END learning_rate=10, loss=absolute_error, max_depth=5, n_estimators=200;, score=-inf total time=   0.3s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 3/3] END learning_rate=10, loss=absolute_error, max_depth=5, n_estimators=200;, score=-inf total time=   0.3s
# [CV 1/3] END learning_rate=10, loss=quantile, max_depth=1, n_estimators=10;, score=-2897644219680737280.000 total time=   0.0s
# [CV 2/3] END learning_rate=10, loss=quantile, max_depth=1, n_estimators=10;, score=-31485477365132144.000 total time=   0.0s
# [CV 3/3] END learning_rate=10, loss=quantile, max_depth=1, n_estimators=10;, score=-1320141821251797504.000 total time=   0.0s
# [CV 1/3] END learning_rate=10, loss=quantile, max_depth=1, n_estimators=100;, score=-16814995651000145931145386000452724291242051641158637770381654429499494557310016595005899044304041096398776976031700708513491001398602829261959216629332159185695323988622921787545922526248960.000 total time=   0.0s
# [CV 2/3] END learning_rate=10, loss=quantile, max_depth=1, n_estimators=100;, score=-181965418148459624034805131116096541539757800721666233977464832710367183495318210436013554339787330676715642140271427406157530406021978020694445834018218119574998033903533202689937117282304.000 total time=   0.0s
# [CV 3/3] END learning_rate=10, loss=quantile, max_depth=1, n_estimators=100;, score=-7660767600555162891991818220179928972350762310334713554203726223589702861503615759427363008175152259674144190431076267305017335383807835017493514612059322245234733413190905370827856436789248.000 total time=   0.0s
# [CV 1/3] END learning_rate=10, loss=quantile, max_depth=1, n_estimators=200;, score=-inf total time=   0.1s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 2/3] END learning_rate=10, loss=quantile, max_depth=1, n_estimators=200;, score=-inf total time=   0.1s
# [CV 3/3] END learning_rate=10, loss=quantile, max_depth=1, n_estimators=200;, score=-inf total time=   0.1s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 1/3] END learning_rate=10, loss=quantile, max_depth=3, n_estimators=10;, score=-3297640036726853632.000 total time=   0.0s
# [CV 2/3] END learning_rate=10, loss=quantile, max_depth=3, n_estimators=10;, score=-8968589107717640192.000 total time=   0.0s
# [CV 3/3] END learning_rate=10, loss=quantile, max_depth=3, n_estimators=10;, score=-3766104101360928768.000 total time=   0.0s
# [CV 1/3] END learning_rate=10, loss=quantile, max_depth=3, n_estimators=100;, score=-17077643543530542515220912409617584475434435501032031991705351063227246177170438798865427946791764718615850719558282788454433712596153653312580132463516923503904618191734195002083540192985088.000 total time=   0.1s
# [CV 2/3] END learning_rate=10, loss=quantile, max_depth=3, n_estimators=100;, score=-62042637072115299990441347454708138709568592323139470742608869364691662858614885515183902864086459891084536542179896872655767368682616354545665812735528138885967017197816736328184253948887040.000 total time=   0.1s
# [CV 3/3] END learning_rate=10, loss=quantile, max_depth=3, n_estimators=100;, score=-21298434647166763931225902007109888253751687968330713402137325216152504132767136283252101931984777388992412235336187375836890742003110258088109654661567012415682023771571072250348318494818304.000 total time=   0.1s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 1/3] END learning_rate=10, loss=quantile, max_depth=3, n_estimators=200;, score=-inf total time=   0.3s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 2/3] END learning_rate=10, loss=quantile, max_depth=3, n_estimators=200;, score=-inf total time=   0.2s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 3/3] END learning_rate=10, loss=quantile, max_depth=3, n_estimators=200;, score=-inf total time=   0.2s
# [CV 1/3] END learning_rate=10, loss=quantile, max_depth=5, n_estimators=10;, score=-3097014002955383808.000 total time=   0.0s
# [CV 2/3] END learning_rate=10, loss=quantile, max_depth=5, n_estimators=10;, score=-9807992422479833088.000 total time=   0.0s
# [CV 3/3] END learning_rate=10, loss=quantile, max_depth=5, n_estimators=10;, score=-2699897253005186048.000 total time=   0.0s
# [CV 1/3] END learning_rate=10, loss=quantile, max_depth=5, n_estimators=100;, score=-24160739888396180507634869769327373326417545652989926275904172616082510074653585939944136127086872462150856327913896012536028339757551202672011421474868215759959871314099478814213356161859584.000 total time=   0.1s
# [CV 2/3] END learning_rate=10, loss=quantile, max_depth=5, n_estimators=100;, score=-56853686154104770525055812028776653510784144811060963413141525889624024852134650703818235777757179493345180352243014148363817989872533093330418899346979032762412522080828242306844529631690752.000 total time=   0.1s
# [CV 3/3] END learning_rate=10, loss=quantile, max_depth=5, n_estimators=100;, score=-20584296544879167889440481093485795678220407918507040607337449121540717778418013908486743900406395864187743094923931663796838607918508066109021797781682594395281169853501678373721017832964096.000 total time=   0.1s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 1/3] END learning_rate=10, loss=quantile, max_depth=5, n_estimators=200;, score=-inf total time=   0.3s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# [CV 2/3] END learning_rate=10, loss=quantile, max_depth=5, n_estimators=200;, score=-inf total time=   0.3s
# [CV 3/3] END learning_rate=10, loss=quantile, max_depth=5, n_estimators=200;, score=-inf total time=   0.3s
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_regression.py:927: RuntimeWarning: overflow encountered in square
#   numerator = (weight * (y_true - y_pred) ** 2).sum(axis=0, dtype=np.float64)
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [ 3.89683106e-001  8.48960244e-001  8.93353359e-001  6.46293237e-001
#   8.67071442e-001  8.68789275e-001  6.65584578e-001  8.14683828e-001
#   8.21000797e-001  3.21298710e-001  7.93329415e-001  8.68371783e-001
#   5.63175467e-001  8.70608604e-001  8.79242047e-001  5.72837509e-001
#   8.79582534e-001  8.72184198e-001 -1.86542451e+000 -6.88668283e-001
#  -6.16310759e-001 -1.22159230e+000  4.42598361e-002  5.36072372e-001
#  -1.15980600e+000  4.43316827e-001  4.86370422e-001  7.81610486e-001
#   8.35876385e-001  8.37095851e-001  6.92048639e-001  6.81592263e-001
#   6.92440652e-001  6.71672528e-001  7.58666819e-001  7.22658059e-001
#   7.75647273e-001  8.60624353e-001  8.52102850e-001  6.08631055e-001
#   6.66822861e-001  6.40863868e-001  6.46975759e-001  6.75585935e-001
#   6.81347742e-001 -2.62644828e-001 -5.09155434e-002 -7.11237430e-002
#  -5.02680507e-001 -5.38396003e-001 -5.02352202e-001 -8.31989217e-001
#  -7.54046367e-001 -6.48848115e-001 -8.09099645e+018 -4.69519582e+190
#              -inf -9.67000717e+018 -5.61126997e+190             -inf
#  -1.25692157e+019 -7.42983985e+190             -inf -6.70866595e+018
#  -3.89303104e+190             -inf -7.74202943e+018 -4.49269066e+190
#              -inf -8.16968639e+018 -4.74063858e+190             -inf
#  -1.41642384e+018 -8.21924289e+189             -inf -5.34411108e+018
#  -3.34729051e+190             -inf -5.20163456e+018 -3.38662409e+190
#              -inf]
#   warnings.warn(
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:961: RuntimeWarning: invalid value encountered in subtract
#   (array - array_means[:, np.newaxis]) ** 2, axis=1, weights=weights
# C:\Users\Suraj Mishra\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:961: RuntimeWarning: overflow encountered in square
#   (array - array_means[:, np.newaxis]) ** 2, axis=1, weights=weights
# GridSearchCV(cv=3, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.1, 1, 10],
#                          'loss': ['squared_error', 'absolute_error',
#                                   'quantile'],
#                          'max_depth': [1, 3, 5],
#                          'n_estimators': [10, 100, 200]},
#              verbose=3)

# %%
y_pred_gcv = grid.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
print(f"mse: {mean_squared_error(y_pred_gcv, y_test)}")
print(f"mae: {mean_absolute_error(y_pred_gcv, y_test)}")
print(f"R_squared: {r2_score(y_pred_gcv, y_test)}")
# Out:
# mse: 702.3739148442303
# mae: 20.674679296077308
# R_squared: 0.9286659907976517

# %%
print(f"Best hyperparameters using RadomsearchCV are: {grid.best_params_}")
# Out:
# Best hyperparameters using RadomsearchCV are: {'learning_rate': 0.1, 'loss': 'squared_error', 'max_depth': 1, 'n_estimators': 200}

# %% [markdown]
# Q4. What is a weak learner in Gradient Boosting?

# %% [markdown]
# In the context of gradient boosting, a weak learner is a model that is only slightly better than random guessing. A weak learner is used to fit a simple model to the data. The predictions of the weak learner are then used to correct the errors made by the previous weak learners.
#
# The weak learners in gradient boosting are typically decision trees. Decision trees are a type of machine learning model that can be used for classification or regression tasks. Decision trees work by splitting the data into smaller and smaller subsets until each subset is homogeneous. The predicted value for a new data point is then the value of the majority class in the subset that the new data point belongs to.

# %% [markdown]
# Q5. What is the intuition behind the Gradient Boosting algorithm?

# %% [markdown]
# The intuition behind the Gradient Boosting algorithm is to build a model that minimizes the loss function by adding weak learners sequentially. The weak learners are trained to correct the errors made by the previous learners. This helps to improve the accuracy of the model over time.
#
# The loss function is a measure of the difference between the predicted values and the actual values. The goal of gradient boosting is to minimize the loss function by adjusting the parameters of the weak learners.

# %% [markdown]
# Q6. How does Gradient Boosting algorithm build an ensemble of weak learners?

# %% [markdown]
# The gradient boosting algorithm works as follows:
#
# Initialize the weights of all data points to be equal.
#
# Train a weak learner on the weighted data.
#
# Calculate the error of the weak learner.
#
# Update the weights of the data points based on the error of the weak learner.
#
# Repeat steps 2-4 until a desired number of weak learners is trained.
#
#
# The final model is the weighted sum of the predictions of the weak learners. The weights are typically adjusted after each weak learner is trained to ensure that the weak learners that are more accurate have a greater weight.

# %% [markdown]
# Q7. What are the steps involved in constructing the mathematical intuition of Gradient Boosting
# algorithm?

# %% [markdown]
#  here are the steps involved in constructing the mathematical intuition of the Gradient Boosting algorithm:
#
# Define the loss function. The loss function is a measure of the difference between the predicted values and the actual values. The goal of gradient boosting is to minimize the loss function.
#
# Choose the weak learners. The weak learners are the models that are used to build the ensemble. They are typically decision trees, but other models can also be used.
#
# Initialize the weights of the data points. The weights of the data points are used to determine how much each data point contributes to the loss function.
#
# Train the first weak learner. The first weak learner is trained on the weighted data.
#
# Calculate the error of the first weak learner. The error of the first weak learner is the difference between the predicted values of the first weak learner and the actual values.
#
# Update the weights of the data points based on the error of the first weak learner. The weights of the data points are updated so that the data points that are misclassified by the first weak learner have a higher weight.
#
# Repeat steps 4-6 until a desired number of weak learners is trained. The final model is the sum of the predictions of the weak learners.
